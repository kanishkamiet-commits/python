# %% [markdown]
# <a href="https://colab.research.google.com/github/KhushiChaudhary-cyber/python_programs/blob/main/bar_chart_example_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import matplotlib library
import matplotlib.pyplot as plt

# Courses offered
courses = ['Python', 'Java', 'C++', 'Web', 'AI']

# Number of students enrolled in each course
students = [40, 35, 25, 30, 20]

# Create bar chart
plt.bar(courses, students)

# Add title and axis labels with units
plt.title("Students Enrolled in Different Courses")
plt.xlabel("Courses")
plt.ylabel("Number of Students")

# Display the graph
plt.show()

# %%
import matplotlib.pyplot as plt

# Product names
products = ['Laptop', 'Mobile', 'Tablet', 'Keyboard', 'Mouse']

# Sales data
sales = [120, 200, 90, 150, 180]

# Plot bar chart
plt.bar(products, sales)

# Labels and title
plt.title("Product Sales")
plt.xlabel("Product")
plt.ylabel("Units Sold")

plt.show()

# %%
import matplotlib.pyplot as plt

# Student names
students = ['A', 'B', 'C', 'D', 'E']

# Marks obtained
marks = [78, 85, 90, 76, 88]

# Create bar chart
plt.bar(students, marks)

# Labels
plt.title("Marks of Students(%)")
plt.xlabel("Student")
plt.ylabel("Marks (%)")

plt.show()

# %%
import matplotlib.pyplot as plt

# Department names
departments = ['HR', 'IT', 'Sales', 'Finance', 'Support']

# Number of employees in each department
employees = [10, 30, 25, 15, 20]

# Plot bar chart
plt.bar(departments, employees)

# Labels
plt.title("Employees in Company Departments")
plt.xlabel("Department")
plt.ylabel("Number of Employees")

plt.show()

# %%
import matplotlib.pyplot as plt

# Book subjects
books = ['Math', 'Science', 'English', 'History', 'Geography']

# Number of books sold
sales = [120, 150, 130, 90, 80]

# Create bar chart
plt.bar(books, sales)

# Labels
plt.title("Number of Books Sold")
plt.xlabel("Book Subject")
plt.ylabel("Copies Sold")

plt.show()

# %%
import matplotlib.pyplot as plt

# Car brands
brands = ['Toyota', 'Honda', 'Hyundai', 'Kia', 'Ford']

# Number of cars sold
sales = [100, 80, 90, 70, 60]

# Plot bar chart
plt.bar(brands, sales)

# Labels
plt.title("Cars Sold by Brand")
plt.xlabel("Brand")
plt.ylabel("Number of Cars Sold")

plt.show()

# %%
import matplotlib.pyplot as plt

# Sports names
sports = ['Cricket', 'Football', 'Tennis', 'Badminton', 'Hockey']

# Number of fans
fans = [200, 150, 80, 90, 60]

# Plot bar chart
plt.bar(sports, fans)

# Labels
plt.title("Sports Popularity")
plt.xlabel("Sport")
plt.ylabel("Number of Fans")

plt.show()

# %%
import matplotlib.pyplot as plt

# City names
cities = ['Delhi', 'Mumbai', 'Bangalore', 'Chennai', 'Kolkata']

# Population data
population = [20, 18, 12, 10, 14]

# Plot bar chart
plt.bar(cities, population)

# Labels
plt.title("Population of Major Cities(In Millions)")
plt.xlabel("City")
plt.ylabel("Population (Millions)")

plt.show()

# %%
import matplotlib.pyplot as plt

# Expense categories
categories = ['Food', 'Rent', 'Travel', 'Shopping', 'Bills']

# Expense amount
amount = [5000, 12000, 3000, 4000, 2500]

# Plot bar chart
plt.bar(categories, amount)

# Labels
plt.title("Monthly Expenses (₹)")
plt.xlabel("Expense Category")
plt.ylabel("Amount (₹)")

plt.show()

# %%
import matplotlib.pyplot as plt

# Subjects
subjects = ['Math', 'Science', 'English', 'History', 'Geography']

# Pass percentage
pass_percent = [80, 75, 85, 70, 78]

# Plot bar chart
plt.bar(subjects, pass_percent)

# Labels
plt.title("Exam Pass Percentage by Subject(%)")
plt.xlabel("Subject")
plt.ylabel("Pass Percentage (%)")

plt.show()
